# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv("tre.csv")

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
test_data = pd.read_csv("tse.csv")

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
def degiskenler(variable):
    cat = train_data[variable]
    sayi=cat.value_counts()
    plt.figure(figsize=(9,3)) 
    plt.bar(sayi.index,sayi)
    plt.xticks(sayi.index,sayi.index.values)
    plt.ylabel("frekans")
    plt.title(variable)
    plt.show()
    print(variable,sayi)

# %%
category=["Survived","Sex","Pclass","Embarked","SibSp","Parch"]

# %%
for i in category:
    degiskenler(i)
# Out:
# Survived Survived
# 0    549
# 1    342
# Name: count, dtype: int64
# Sex Sex
# male      577
# female    314
# Name: count, dtype: int64
# Pclass Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
# Embarked Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64
# SibSp SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64
# Parch Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
category1=["Cabin","Name","Ticket"]

# %%
for c in category1:
    print(train_data[c].value_counts())
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64
# Name
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: count, Length: 891, dtype: int64
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %%
def histogram(variable):
    plt.figure(figsize=(10,3))
    plt.hist(train_data[variable])
    plt.xlabel(variable)
    plt.ylabel("frekans")
    plt.title(variable)
    plt.show()

# %%
sayisal=["Fare","Age","PassengerId"]

# %%
for i in sayisal:
    histogram(i)

# %%
#bilet sınıfına göre hayatta kalma oranı
train_data[["Pclass","Survived"]]
# Out:
#      Pclass  Survived
# 0         3         0
# 1         1         1
# 2         3         1
# 3         1         1
# 4         3         0
# ..      ...       ...
# 886       2         0
# 887       1         1
# 888       3         0
# 889       1         1
# 890       3         0
#
# [891 rows x 2 columns]

# %%
train_data[["Pclass","Survived"]].groupby(["Pclass"],as_index=False).mean()
#groupby ile birbiri ile ilgili ilişkisini inceleriz
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
train_data[["Pclass","Survived"]].groupby(["Pclass"],as_index=False).mean().sort_values(by="Survived",ascending=True)
# Out:
#    Pclass  Survived
# 2       3  0.242363
# 1       2  0.472826
# 0       1  0.629630

# %%
train_data[["Sex","Survived"]].groupby(["Sex"],as_index=False).mean().sort_values(by="Survived",ascending=True)
# Out:
#       Sex  Survived
# 1    male  0.188908
# 0  female  0.742038

# %%
train_data[["SibSp","Survived"]].groupby(["SibSp"],as_index=False).mean().sort_values(by="Survived",ascending=True)
# Out:
#    SibSp  Survived
# 5      5  0.000000
# 6      8  0.000000
# 4      4  0.166667
# 3      3  0.250000
# 0      0  0.345395
# 2      2  0.464286
# 1      1  0.535885

# %%
train_data[["Parch","Survived"]].groupby(["Parch"],as_index=False).mean().sort_values(by="Survived",ascending=True)
# Out:
#    Parch  Survived
# 4      4  0.000000
# 6      6  0.000000
# 5      5  0.200000
# 0      0  0.343658
# 2      2  0.500000
# 1      1  0.550847
# 3      3  0.600000

# %%
train_data_len=len(train_data)

# %%
train_data1=pd.concat([train_data,test_data],axis=0).reset_index(drop=True)
#pd.concat pandasta iki pdyi birleştiriyoruz
#axisi 1 verseydik iki data yan yana gelicekti ama 0 olunca alt alt gelir.

# %%
train_data1
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %%
train_data1.columns[train_data.isnull().any()]
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
train_data1.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
train_data1[train_data1["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62       1.0       1                        Icard, Miss. Amelie
# 829          830       1.0       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
train_data1.boxplot(column="Fare", by="Embarked")
# Out:
# <Axes: title={'center': 'Fare'}, xlabel='Embarked'>

# %%
train_data1["Embarked"]=train_data["Embarked"].fillna("C")

# %%
train_data1[train_data1["Embarked"].isnull()]
# Out:
#       PassengerId  Survived  Pclass  \
# 891           892       NaN       3
# 892           893       NaN       3
# 893           894       NaN       2
# 894           895       NaN       3
# 895           896       NaN       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                               Name     Sex   Age  SibSp  \
# 891                               Kelly, Mr. James    male  34.5      0
# 892               Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 893                      Myles, Mr. Thomas Francis    male  62.0      0
# 894                               Wirz, Mr. Albert    male  27.0      0
# 895   Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ...                                            ...     ...   ...    ...
# 1304                            Spector, Mr. Woolf    male   NaN      0
# 1305                  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                  Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                           Ware, Mr. Frederick    male   NaN      0
# 1308                      Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked
# 891       0              330911    7.8292   NaN      NaN
# 892       0              363272    7.0000   NaN      NaN
# 893       0              240276    9.6875   NaN      NaN
# 894       0              315154    8.6625   NaN      NaN
# 895       1             3101298   12.2875   NaN      NaN
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN      NaN
# 1305      0            PC 17758  108.9000  C105      NaN
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN      NaN
# 1307      0              359309    8.0500   NaN      NaN
# 1308      1                2668   22.3583   NaN      NaN
#
# [418 rows x 12 columns]
